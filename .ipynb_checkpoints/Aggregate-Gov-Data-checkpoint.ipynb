# %% [markdown]
# # Aggregating Gov Data
#
# ## Aggregating government MapServer data into a csv file.
#
# The data from the map shown on the homepage of the Affordable Housing Tax Increment Financing under the link ["Visit Searchable Database"](https://experience.arcgis.com/experience/878a77d336984fd7988be8b61c0a4233#data_s=id%3AdataSource_1-198cd7bba2a-layer-8%3A39359).

# %% [markdown]
# ### housing.housing.TIF_Application_flat (ID: 0)
# https://egis.baltimorecity.gov/egis/rest/services/Housing/TIF_Application_Data/MapServer/0/query
# 5,206 records
#
# Columns of interest:
# - BVRI_FY26
# - BLOCKLOT
# - FULLADDR
# - Neighborhood
#
# Querying for just the [Baltimore Vacants Reinvestment Initiative](https://dhcd.maryland.gov/Reinvest-Baltimore/Pages/BVRI.aspx) lots for FY26

# %%
import requests
import variable
import csv

fieldnames = ['FULLADDR', 'BLOCKLOT', 'Ownership', 'Orig_Criteria', 'Current_Criteria', 'VRPA']
req = requests.get(variable.TIF_APPLICATION_FLAT_QUERY(fieldnames))
rows = req.json()['features']

with open('BVRI_FY26_lots.csv', 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames, dialect='unix')
    writer.writeheader()
    for row in req.json()['features']:
        writer.writerow(row['attributes'])
# Out:
# Traceback (most recent call last):
#
#   File ~/Github/baltimore-tif/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 2
#     import variable
#
#   File ~/Github/baltimore-tif/variable.py:4
#     return f"https://egis.baltimorecity.gov/egis/rest/services/Housing/TIF_Application_Data/MapServer/0/query?where=BVRI_FY26+%3D+%27Yes%27&text=&objectIds=&time=&timeRelation=esriTimeRelationOverlaps&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&distance=&units=esriSRUnit_Foot&relationParam=&outFields={",".join(fields)}&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&havingClause=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&historicMoment=&returnDistinctValues=false&resultOffset=&resultRecordCount=&returnExtentOnly=false&sqlFormat=none&datumTransformation=&parameterValues=&rangeValues=&quantizationParameters=&featureEncoding=esriDefault&f=json"
#                                                                                                                                                                                                                                                                                                                                                           ^
# SyntaxError: f-string: expecting '}'

# %% [markdown]
# #### GET request issue
#
# GET requests are constrained by a character limit, so I needed to use a POST request instead with where="VBN_Issued is not null" to use the neighborhood polygon for the input geometry query
#
# I built the query like this:
# 1. Make a GET request from https://egis.baltimorecity.gov/egis/rest/services/Housing/dmxFocusAreas/MapServer/2/query using "Name" param and return
#     - wkid
#     - geometry
# 2. Build the dict {"rings": [[[x1,y1]}, [x2,y2],..]], "spatialReference": { "wkid": 123456}} to use for the polygon input geometry
# 3. POST request with dict in input geometry variable in the [CoDeMap](https://cels.baltimorehousing.org/codemapv2ext/) Ownership data

# %%
import pandas as pd
import datetime as dt
import requests
import variable
import csv

fieldnames = ['BLOCK','BLOCKLOT','FULLADDR','TAXBASE','PERMHOME','SALEDATE','OWNER_1','OWNER_2','OWNER_3']

def get_Neighborhood_Input_Geometry(neighborhood, fieldnames):
    location_req = requests.get(variable.NEIGHBORHOOD_BOUNDARIES(neighborhood))
    location_json = location_req.json()
    input_geometry = {}
    
    for k, v in location_json.items():
        if k == 'spatialReference':
            input_geometry['spatialReference'] = v
            continue
        if k == 'features':
            input_geometry['rings'] = v[0]['geometry']['rings']
            break
    
    return {
        'geometry': f'{input_geometry}', 
        'where': '(VBN_Issued is not null)', 
        'geometryType': 'esriGeometryPolygon',
        'spatialRel': 'esriSpatialRelIntersects',
        'outFields': ','.join(fieldnames),
        'returnGeometry': 'false',
        'f': 'json'
    }

def postreq_Neighborhood_Data(query, neighborhood, fieldnames):
    payload = get_Neighborhood_Input_Geometry(neighborhood, fieldnames)
    req2 = requests.post(query, data=payload)
    
    if req2.ok:
        data = []
        for vacant in req2.json()['features']:
            data.append(vacant['attributes'])
        df = pd.DataFrame(data)

        # Formatting
        owner_cols = [c for c in df.columns if "OWNER" in c]
        string_types = [c for c in df.columns if c not in ["TAXBASE", "SALEDATE"]]
        df[string_types] = df[string_types].astype("string")
        df.loc[:, owner_cols] = df[owner_cols].apply(lambda x: x.str.strip())
        df['SALEDATE'] = pd.to_datetime(df['SALEDATE'], format='%m%d%Y')
        
        return df

westport_data = postreq_Neighborhood_Data(
    query='https://egis.baltimorecity.gov/egis/rest/services/Housing/dmxOwnership_v3/MapServer/0/query', 
    neighborhood='Westport', 
    fieldnames=fieldnames
)
westport_data

# %%
def filter_by_owners_count(df):
    # Filter rows with owners that only appear once
    return df[df.groupby('OWNER_1')['OWNER_1'].transform('size') > 1]

filter_by_owners_count(westport_data)['OWNER_1'].value_counts()

# %%
def write_to_csv(neighborhood, df):
    file = f'{neighborhood}_lots.csv'
    return df.to_csv(file, index=False)

write_to_csv('Westport', filter_by_owners_count(westport_data))

# %% [markdown]
# ### TIF_List
# https://egis.baltimorecity.gov/egis/rest/services/Housing/TIF_List/
#
# Query for "Tranche Zero" properties for increment
# https://egis.baltimorecity.gov/egis/rest/services/Housing/TIF_List/MapServer/1/query
#
# Columns I want:
# - Address
# - Blocklot
# - Orig_Criteria (these can be split by query)
#   - 2023 Rehabs/Sales for First Increment
#   - 2024 Rehabs/Sales for First Increment <- could be good areas to get a progress update by combining with market data?
# - City-Owned
#   - Yes/No

# %% [markdown]
# ### Properties (ID: 0)
# https://egis.baltimorecity.gov/egis/rest/services/Housing/dmxOwnership/MapServer/0/
#
# Questions to explore with this data:
# - Who is receiving these grants? How many grants are being given out? What’s the multiplicity of the grant received per recipient.
# - Based on the BVRI_FY26 money, who bought properties in 25/26, how much did they sell for? How much money did they get?
# - How much private equity funds? Who are private equity?
#
# ```SQL
# <field name> IN (<field value>, <field value>)
# ```

# %% [markdown]
# ## Who are the developers in Baltimore City?
# - Does market data reflect affordable housing? The people who can afford to rehab a vacant even with the TIF cash injection still have to be pretty flush with cash.
#     - Do the housing prices of rehabbed homes in VRPG areas reflect income-levels of the areas they are in?
# - Are there any public infrastructure programs being funded by these grants?

# %% [markdown]
# ## Dictionary
# - **VRPG**: [Vacancy Reducation Priority Geographies](https://app.powerbigov.us/view?r=eyJrIjoiY2YwMWNlZTItMjFkYy00OTZiLThjMGEtNWM4YzZhNDViMzJjIiwidCI6IjMxMmNiMTI2LWM2YWUtNGZjMi04MDBkLTMxOGU2NzljZTZjNyJ9), a term originating from Baltimore City’s Framework for Community Development "which designate specific areas as targets for intensive effort to eliminate
# vacant properties."
# - **BVRI**: [Baltimore Vacants Reinvestment Initiative](https://dhcd.maryland.gov/Reinvest-Baltimore/Pages/BVRI.aspx), offers grants and loans to Baltimore City, Maryland Stadium Authority, and community development organizations (CDOs) to demo, renovate, or aggregate vacant lots for housing, mixed-use projects, and greenspaces.
# - **VRPA**: Violence Reduction Priority Areas
# - **MCC**: Mayor and City Council (MCC) owned lots
# - **CDC**: Community development corporations (CDCs)
